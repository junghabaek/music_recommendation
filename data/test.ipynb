# %%
import pandas as pd

# %%
df2 = pd.read_csv('./final_movie.csv', index_col=0)
df2.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#    Netflix  Hulu  Prime Video  Disney+  Type                       Directors  \
# 0      1.0     0            0        0     0               Christopher Nolan
# 1      1.0     0            0        0     0  Lana Wachowski,Lilly Wachowski
# 2      1.0     0            0        0     0         Anthony Russo,Joe Russo
# 3      1.0     0            0        0     0                 Robert Zemeckis
# 4      1.0     0            1        0     0                    Sergio Leone
#
#                              Genres                       Country  \
# 0  Action,Adventure,Sci-Fi,Thriller  United States,United Kingdom
# 1                     Action,Sci-Fi                 United States
# 2           Action,Adventure,Sci-Fi                 United States
# 3           Adventure,Comedy,Sci-Fi                 United States
# 4                           Western      Italy,Spain,West Germany
#
#                   Language  Runtime                       re_title  \
# 0  English,Japanese,French    148.0                      inception
# 1                  English    136.0                     the-matrix
# 2                  English    149.0          avengers-infinity-war
# 3                  English    116.0             back-to-the-future
# 4                  Italian    161.0  the-good-the-bad-and-the-ugly
#
#     music_director                                          poster  in_spe
# 0      Hans Zimmer  https://www.soundtrack.net/img/movie/30396.jpg   False
# 1        Don Davis  https://www.soundtrack.net/img/movie/16705.jpg   False
# 2   Alan Silvestri  https://www.soundtrack.net/img/movie/41685.jpg   False
# 3   Alan Silvestri   https://www.soundtrack.net/img/movie/1695.jpg   False
# 4  Ennio Morricone  https://www.soundtrack.net/img/movie/10072.jpg   False

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5619 entries, 0 to 5619
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               5619 non-null   int64
#  1   Title            5619 non-null   object
#  2   Year             5619 non-null   int64
#  3   Age              3502 non-null   object
#  4   IMDb             5598 non-null   float64
#  5   Rotten Tomatoes  3323 non-null   object
#  6   Netflix          5619 non-null   float64
#  7   Hulu             5619 non-null   int64
#  8   Prime Video      5619 non-null   int64
#  9   Disney+          5619 non-null   int64
#  10  Type             5619 non-null   int64
#  11  Directors        5468 non-null   object
#  12  Genres           5617 non-null   object
#  13  Country          5603 non-null   object
#  14  Language         5563 non-null   object
#  15  Runtime          5556 non-null   float64
#  16  re_title         5619 non-null   object
#  17  music_director   5619 non-null   object
#  18  poster           4245 non-null   object
#  19  in_spe           5619 non-null   bool
# dtypes: bool(1), float64(3), int64(6), object(10)
# memory usage: 883.5+ KB

# %%
check = df2[['ID', 'Genres']]

# %%
check.head()
# Out:
#    ID                            Genres
# 0   1  Action,Adventure,Sci-Fi,Thriller
# 1   2                     Action,Sci-Fi
# 2   3           Action,Adventure,Sci-Fi
# 3   4           Adventure,Comedy,Sci-Fi
# 4   5                           Western

# %%
check = pd.concat([check, check['Genres'].str.split(',', expand=True)], axis=1)

# %%
check
# Out:
#          ID                                  Genres            0          1  \
# 0         1        Action,Adventure,Sci-Fi,Thriller       Action  Adventure
# 1         2                           Action,Sci-Fi       Action     Sci-Fi
# 2         3                 Action,Adventure,Sci-Fi       Action  Adventure
# 3         4                 Adventure,Comedy,Sci-Fi    Adventure     Comedy
# 4         5                                 Western      Western       None
# ...     ...                                     ...          ...        ...
# 5615  16722  Comedy,Family,Adventure,Fantasy,Sci-Fi       Comedy     Family
# 5616  16723                      Documentary,Family  Documentary     Family
# 5617  16725                    Comedy,Family,Sci-Fi       Comedy     Family
# 5618  16739                        Adventure,Family    Adventure     Family
# 5619  16740            Comedy,Family,Fantasy,Horror       Comedy     Family
#
#               2         3       4     5     6     7
# 0        Sci-Fi  Thriller    None  None  None  None
# 1          None      None    None  None  None  None
# 2        Sci-Fi      None    None  None  None  None
# 3        Sci-Fi      None    None  None  None  None
# 4          None      None    None  None  None  None
# ...         ...       ...     ...   ...   ...   ...
# 5615  Adventure   Fantasy  Sci-Fi  None  None  None
# 5616       None      None    None  None  None  None
# 5617     Sci-Fi      None    None  None  None  None
# 5618       None      None    None  None  None  None
# 5619    Fantasy    Horror    None  None  None  None
#
# [5619 rows x 10 columns]

# %%
check.drop(['Genres'], axis=1, inplace=True)

# %%
check.to_csv('genres.csv')
